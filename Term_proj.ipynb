# %%
# !python train.py
# Out:
# ...
# Save path: checkpoints/
# Using Device: cuda:0
# Number of usable GPUs: 1
# Batch_size: 64
# learning_rate: 0.0001
# Epochs: 12
# ...
# [Epoch 1 / 12]
# 100% 328/328 [02:45<00:00,  1.98it/s]
# Epoch 1
# train_loss : 0.4982975372681167
# train_accuracy : 87.008%
# Current Learning Rate: 0.0001
# [Epoch 2 / 12]
# 100% 328/328 [02:41<00:00,  2.03it/s]
# Epoch 2
# train_loss : 0.2971724873499536
# train_accuracy : 90.956%
# Current Learning Rate: 0.0001
# [Epoch 3 / 12]
# 100% 328/328 [02:41<00:00,  2.03it/s]
# Epoch 3
# train_loss : 0.2632846923363281
# train_accuracy : 91.897%
# Current Learning Rate: 0.0001
# [Epoch 4 / 12]
# 100% 328/328 [02:39<00:00,  2.06it/s]
# Epoch 4
# train_loss : 0.23101230531294897
# train_accuracy : 92.694%
# Current Learning Rate: 0.0001
# [Epoch 5 / 12]
# 100% 328/328 [02:39<00:00,  2.05it/s]
# Epoch 5
# train_loss : 0.21277807655221806
# train_accuracy : 93.306%
# Current Learning Rate: 1e-05
# [Epoch 6 / 12]
# 100% 328/328 [02:42<00:00,  2.01it/s]
# Epoch 6
# ...

# %% [markdown]
# # 새 섹션

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python test.py
# Out:
# 100% 1309/1309 [00:38<00:00, 33.90it/s]
# Test Accuracy : 0.94404

# %%
# !python run.py
# Out:
# 100% 7/7 [00:02<00:00,  2.40it/s]
